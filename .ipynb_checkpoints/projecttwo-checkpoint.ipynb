# %%
import pandas as pd
import sqlite3
import os

# %%
db = sqlite3.connect("foreigntrips.db")

# %%
df1 = pd.read_csv("trips.csv")

# %%
df1.to_sql("travel", db, if_exists="replace")
# Out:
# /Users/jessicakaiser/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:2712: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
def run_query(query):
    return pd.read_sql_query(query, db)
os.getcwd()
# Out:
# '/Users/jessicakaiser/hello-world'

# %%
df1
# Out:
#         Unnamed: 0      id  duration           start_date  start_station  \
# 0                0       1         9  2011-07-28 10:12:00           23.0
# 1                1       2       220  2011-07-28 10:21:00           23.0
# 2                2       3        56  2011-07-28 10:33:00           23.0
# 3                3       4        64  2011-07-28 10:35:00           23.0
# 4                4       5        12  2011-07-28 10:37:00           23.0
# ...            ...     ...       ...                  ...            ...
# 638706      638706  645381       360  2012-11-10 11:41:00           47.0
# 638707      638707  645382       360  2012-11-10 11:42:00           57.0
# 638708      638708  645383      1800  2012-11-10 11:48:00          102.0
# 638709      638709  645384        60  2012-11-10 11:43:00           16.0
# 638710      638710  645385       660  2012-11-10 11:43:00           57.0
#
#                    end_date  end_station bike_number    sub_type zip_code  \
# ...

# %%
query = """
SELECT * 
FROM sqlite_master
ORDER BY name;
"""
run_query(query)
# Out:
#     type             name tbl_name  rootpage  \
# 0  index  ix_travel_index   travel         3
# 1  table           travel   travel         2
#
#                                                  sql
# 0  CREATE INDEX "ix_travel_index"ON "travel" ("in...
# 1  CREATE TABLE "travel" (\n"index" INTEGER,\n  "...

# %%
query = """
SELECT * 
FROM travel;
"""
run_query(query)
# Out:
#          index  Unnamed: 0      id  duration           start_date  \
# 0            0           0       1         9  2011-07-28 10:12:00
# 1            1           1       2       220  2011-07-28 10:21:00
# 2            2           2       3        56  2011-07-28 10:33:00
# 3            3           3       4        64  2011-07-28 10:35:00
# 4            4           4       5        12  2011-07-28 10:37:00
# ...        ...         ...     ...       ...                  ...
# 638706  638706      638706  645381       360  2012-11-10 11:41:00
# 638707  638707      638707  645382       360  2012-11-10 11:42:00
# 638708  638708      638708  645383      1800  2012-11-10 11:48:00
# 638709  638709      638709  645384        60  2012-11-10 11:43:00
# 638710  638710      638710  645385       660  2012-11-10 11:43:00
#
#         start_station             end_date  end_station bike_number  \
# 0                23.0  2011-07-28 10:12:00         23.0      B00468
# ...
